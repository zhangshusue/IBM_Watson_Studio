# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Shu Zhang**
# Economist/Business Consultant

# %% [markdown]
# _I am interested in data science because I want to improve my data analytical skills given the recently rapid development in Data Science filed and to extend its application in Economic/Business analysis._

# %% [markdown]
# ### The following code is to do a simple calculation and assign the output value:

# %%
x <- 1+1
x
# Out:
# [1] 2

# %% [markdown]
# **Horizontal Rules (3 ways in numbered list)**
#
#  1. Hyphens
#    * `bulletted item 1`
#    * `bulletted item 2`
#    * `bulletted item 3`
#   ---
#
#  2. Asterisks
#
#   ***
#
#  3. Underscores
#  ___

# %% [markdown]
# ### This is a markdown table

# %% [markdown]
# |fruit | color | price |
# | ---  |  ---  |  ---  |
# | apple|  red  |   $6  |
# | pear | green |   $4  |
# |banana| yellow|   $8  |

# %% [markdown]
# <s>this is strike through text</s>

# %% [markdown]
# `Thank you very much!`

# %% [markdown]
# <div>
# <img style="float: left;" src="https://raw.githubusercontent.com/zhangshusue/IBM_Watson_Studio/master/thank_you_note.jpg" width="500"/>
# </div>
